# %%
# 이전 방식
import os
from openai import OpenAI
client = OpenAI()

client.api_key = os.environ['OPENAI_API_KEY']

# GPT API를 통해 요청 보내고 결과 가져오는 부분
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "user", "content": "Python에 대해 알려주세요"},
    ],
)
print(response)

# %%
# 최근 방식
from openai import OpenAI
client = OpenAI()
client=OpenAI(api_key=)
response = client.responses.create(
    model="gpt-4.1",
    input="Python에 대해 알려주세요.",
    instructions='친절한 파이썬 강사처럼 설명해주세요.'
)

print(response.output_text)

# %% [markdown]
# temperature와 role 변화주면서 테스트하기

# %%
import os
from openai import OpenAI
client=OpenAI()

response=client.chat.completions.create(
model= 'gpt-4o-mini',
messages=[{'role': 'system', 'content': '핀테크 전문가로서 대답해줘', 'role':'user',
          'content': '미국에서 가장 주목받는 핀테크 기업목록 10개를 알려주고 \
          주요 서비스에 대해서 알려주세요.'}
    
],
temperature=0) # temperature: 사실에 기반 0 상상력 필요할 때 1, 2까지 조절할 수 있음
print(response.choices[0].message.content)

# %% [markdown]
# # gradio를 이용한 openAI 챗봇

# %%
import os
import gradio as gr
from openai import OpenAI

# 환경변수에서 API 키 불러오기 (또는 직접 할당 가능)
# os.environ['OPENAI_API_KEY'] = "your-api-key"
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# 대화 함수 정의
def chatbot(message):
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "핀테크 전문가로서 대답해줘"},
            {"role": "user", "content": message}
        ],
        temperature=0
    )
    return response.choices[0].message.content

# Gradio UI 구성
iface = gr.Interface(
    fn=chatbot,
    inputs=gr.Textbox(label="질문을 입력하세요"),
    outputs=gr.Textbox(label="답변"),
    title="핀테크 전문가 챗봇",
    theme="default"
)

iface.launch()

# %%
demo.close()

# %%
df.to_csv('embeddings.csv')

# %%
def answer_question(question, conversation_history):
    df=pd.read_csv("embeddings.csv")
    
    try: 
        response
