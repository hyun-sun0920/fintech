# %%
num=0
for i in range(100, 0, -1):
    num+=i
print(num)
# Out:
#   Cell In[1], line 2
#     for i in range(100, 0, -1):
#                                ^
# IndentationError: expected an indented block

# %%
ban=list(range(1,101))[::-1]
print(ban)
sum(ban)

# %%
a=list(range(1, 101))
a.reverse()
a
sum(a)

# %%
num=0
for i in reversed(range(1, 101)):
    num+=i
print(num)

# %%
for idx, i in enumerate(s):
    print(idx, i)
# Out:
#   Cell In[2], line 1
#     for idx, i in enumerate(s):
#                                ^
# IndentationError: expected an indented block

# %%
for idx, i in enumerate(s):
    if idx%2==0:
        continue
    else:
        print(i)

# %%
for i in range(1,11):
    print(f"{i}는 짝수입니다.") if i%2==0 else print(f"{i}는 홀수입니다.")

# %%
l1=[]
for i in range(1,11):
    l1.append(i)
l1

# %%
import time

# %%
# %%time
a=[]
for i in range(1, 200000):
    a.append(i+5)
print(a[:10])

# %%
# %%time
b=[i+5 for i in range(1, 200000)]
print(b[:10])

# %%
l1=[]
for i in range(1,11):
    if i%2==0:
        l1.append(i)
l1

# %%
l2=[]
l2=[i for i in range(1, 11) if i%2==0]
l2

# %%
for i in range(2, 10) for j in range(1, 10)

# %%
file=open("test.txt",'w')
file.write("파일 만들기 연습4")
file.close()

# %%
file1=open('test.txt','r')
my_file=file1.read()
file.close()
print(my_file)

# %%
my_file

# %%
with open("test2.txt",'a') as file3:
    file3.write("\nwith open을 사용하면 파일ㅇ")

# %%
with open('test2.txt','r') as file4:
    data=file4.read()
print(data)

# %%
with open('test-utf-8.txt','w', encoding='utf-8') as file5:
    file5.write("이것은 with open으로 만들 ")

# %%
with open('test_utf-8.txt','r') as file6:
    file6_data=file6.read()

# %% [markdown]
# with open("./data/서울특별시_관광지입장정보.json",'r', encoding='utf-8') as file7:
#     trip_info

# %%
print(type())

# %%
import json

# %%
data=json.loads(trip_info)

# %%
data[0].items()

# %%
type(data[0])

# %%
list(data[0].keys)

# %%
for i in range(len(data)):
    ForNum=data[i]['ForNum']
    
    fn.append(ForNum)

# %%
import pandas as pd

# %%
result_df=pd.DataFrame(result)
result_df

# %%
import json

# %%
data = json.loads(trip_info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = json.loads(trip_info)
#
# NameError: name 'trip_info' is not defined

# %%
data[0]['ForNum']

# %%
for key in data[0]:
    print(key)

# %%
result={}
for key in data[0]:
    temp=[]
    for dicts in data:
        temp.append(dicts)

# %%
result2={}
for dicts in data[:2]:
    for key, value in dicts.items():
        result2.setdefault(key,[]).append(value)
        print(result2)

# %%
result2={}
for dicts in data[:2]:
    for key, value in dicts.items():
        result2.setdefault(key,[]).append(value)
        print(result2)

# %%
year_mon=[]
sido=[]
place=[]
foriners=[]
total=[]

# %%
result={}
for key in data[0]:
    value_list=[]
    for item in data:
        value_list.append(item[key])
    print(key, value_list)
    result[key]=value_list
result

# %%
result={}
for key in data[0]:
    value_list=[]
    for item in data:
        value_list.append(item[key])
    print(key, value_list)
    result[key]=value_list
    
result

# %%
result={}
for key in data[0]:
    value_list=[]
    for item in data:
        value_list.append(item[key])
    print(key, value_list)
    result[key]=value_list

# %%
result_df=pd.DataFrame(result)
result_df

# %%
d2={}
d2.setdefault("key", 3)
d2

# %%
dic_result={}
for dicts in data:
    for key, value in dicts.items():
        dic_result.setdefault(key,[]).append(value)
dic_result

# %%
ㅑ
