# %% [markdown]
# # 파이썬 기초 문법
# * 파이썬의 주석은 문장 앞에 #을 붙여서 만든다.
# * 파이썬은 들여쓰기를 사용해서 코드를 구분해서 작성한다.
# * 들여쓰기는 4칸이 기본, google colab은 2칸
# * 변수를 만들때 스네이크 표기법을 사용한다. ex)user_name
# * 클래스를 만들 때는 카멜 표기법을 사용한다. ex)UserName

# %% [markdown]
# # print문
# * print함수 안에 있는 내용을 출력해주는 함수
# * print(출력할 내용)
# * print(1) 출력할 내용이 숫자인 경우, 변수인 경우 따옴표 X
# * print("hello world") 출력할 내용이 문자, 문자열인 경우에는 반드시 따옴표가 필요.
# * 단 ""나 '' 모두 사용가능.

# %%
print(1)
# Out:
# 1

# %%
print(3.14)
# Out:
# 3.14

# %%
print("파")
# Out:
# 파

# %%
print('파이썬')
# Out:
# 파이썬

# %%
# 따옴표까지 같이 출력하고 싶을때는 섞어서
print("이것은 '파이썬'이다.")
# Out:
# 이것은 '파이썬'이다.

# %% [markdown]
# # print문의 옵션
# * sep: 구분자-print 문 안에 여러개의 자료를 출력할 때 자료를 구분해주는 문자
# * 기본값은 "" 공백

# %%
print("이것은", '파이썬', '입니다.')
# Out:
# 이것은 파이썬 입니다.

# %%
print("이것은", '파이썬', '입니다.', sep="_")
# Out:
# 이것은_파이썬_입니다.

# %%
print("헐크","아이어맨","스파이더맨",sep="vs")
# Out:
# 헐크vs아이어맨vs스파이더맨

# %% [markdown]
# *end옵션 - print가 끝나고 실행될 옵션
# *기본값=\n-이스케이프 문자 new line 새줄

# %%
print("헐크","아이어맨","스파이더맨",sep="vs")
print("헐크","아이어맨","스파이더맨",sep="vs")
# Out:
# 헐크vs아이어맨vs스파이더맨
# 헐크vs아이어맨vs스파이더맨

# %%
#end값을 공백""으로 준 경우
print("헐크","아이어맨","스파이더맨",sep="vs", end="   ")
print("헐크","아이어맨","스파이더맨",sep="vs")
# Out:
# 헐크vs아이어맨vs스파이더맨   헐크vs아이어맨vs스파이더맨

# %%
#end값을 공백"\t" (tap)으로 준 경우
print("헐크","아이어맨","스파이더맨",sep="vs", end="\t")
print("헐크","아이어맨","스파이더맨",sep="vs")
# Out:
# 헐크vs아이어맨vs스파이더맨	헐크vs아이어맨vs스파이더맨

# %%
#end값을 공백 "\r" (carriage return)으로 준 경우: 밑에 줄이 위에 줄 덮음
print("헐크","아이어맨","스파이더맨",sep="vs", end="\r")
print("헐크","아이어맨","스파이더맨",sep="vs")
# Out:
# 헐크vs아이어맨vs스파이더맨

# %%
#end값을 공백"\n" (new line)으로 준 경우
print("헐크","아이어맨","스파이더맨",sep="vs", end="\n\n")
print("헐크","아이어맨","스파이더맨",sep="vs")
# Out:
# 헐크vs아이어맨vs스파이더맨
#
# 헐크vs아이어맨vs스파이더맨

# %% [markdown]
# #함수의 옵션보기
# *함수의 옵션은 괄호 안에 커서를 놓고 shift+tap으로 볼 수 있다.
# ![Image20250307103724.png](attachment:Image20250307103724.png)

# %%
#shift+tap
print()

# %% [markdown]
# #변수
# * 자료를 담는 택배상자
# * 택배 상자는 1개만 넣을 수 있다.
# * 변수는 영문과 숫자를 조합해서 만들 수 있다.
# * 변수명의 시작은 반드시 영문자로 시작 or _로 시작
# * 변수명이 숫자로 시작하거나 -등의 특수문자로 시작하면 오류
# * 예약어(이미 파이썬에서 사용하고 있는 함수명, 문법용 단어) ex) for, list, if, id는 변수명으로 사용할 수 없다.
#
# *주의!! 예악어를 써도 파이썬에서는 변수가 만들어진다. -> id가 변수가 되어버리는 상황발생
# *그러므로 예악어를 잘 기억해두자!!

# %%
id(a)
# Out:
# 1934082861360

# %% [markdown]
# *변수명은 스네이크 표기법으로 만든다.
# *변수명=자료
# *=는 같다라는 표시가 X, 등호 오른쪽의 자료를 왼쪽 변수에 할당한다.

# %% [markdown]
# 변수에는 자료가 1개만 들어간다

# %%
a=1
print(a)
# Out:
# 1

# %%
c="문자열은 길이에 상관없이 들어가요"
print(c)
# Out:
# 문자열은 길이에 상관없이 들어가요

# %%
#변수명은 스네이크 표기법으로 만든다.
user_name="핀테크님"
print(user_name)
# Out:
# 핀테크님

# %%
user_name
# Out:
# '핀테크님'

# %%
a=3

# %%
b="3"

# %%
print(a,b)
# Out:
# 3 3

# %%
a
# Out:
# 3

# %%
b
# Out:
# '3'

# %% [markdown]
# 변수 여러 개를 한 번에 만들기

# %%
a, b, c=1, 3, "오"

# %%
print(a, b, c)
# Out:
# 1 3 오

# %% [markdown]
# 변수 삭제하기 del 변수명

# %%
b
# Out:
# 3

# %%
del b

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 b
#
# NameError: name 'b' is not defined
