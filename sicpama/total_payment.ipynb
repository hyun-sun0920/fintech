# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://dev:pwd@localhost:3306/orders")

# %%
import pandas as pd

query = """
SELECT 
    o.customerId,
    o.storeId,
    p.paidAmount,
    o.id AS order_id,
    o.paymentStatus AS order_status,
    p.status AS payment_status,
    p.providerPaymentName
FROM payments p
INNER JOIN orders o ON p.id = o.paymentId
WHERE
    -- 온라인 결제
    (
        o.paymentId IS NOT NULL
        AND o.paymentStatus = 'success'
        AND p.status IN ('SUCCESS', '0000')
    )
    OR
    -- 오프라인 결제
    (
        o.paymentStatus != 'success'
        AND p.status IN ('SUCCESS', '0000')
        AND p.providerPaymentName != 'none'
    )
"""

df = pd.read_sql(query, engine)

# 결과 출력
display(df)
# Out:
#                        customerId  storeId  paidAmount  \
# 0      01GZZ0C5HVG9049C8AT5Y96HFS        1      4000.0
# 1      01GZZ89SHGZJM84N36QSAMPVKB        1     29000.0
# 2      01GZZ8HDKTEZHEYVQXGBVZMYPK        1     42300.0
# 3      01GZZ9TFH848XS2P1XCDKQJ38K        1     32000.0
# 4      01GZZ0C5HVG9049C8AT5Y96HFS        2       200.0
# ...                           ...      ...         ...
# 25304  01JV4ND9809PTZWV7FZP7QN314        3      9900.0
# 25305  01JV4P5BSD3QADXNNZYWHJWKC2        3     17800.0
# 25306  01JV6B29902CTGMCB83PD63DXK        3     23400.0
# 25307  01JV6BAA62M7ZSYFK5CSQTQQC2        3      9900.0
# 25308  01JV6DBGH9Y0F51GFJ4KGKEC9K        3     11400.0
#
#                          order_id order_status payment_status  \
# 0      01GZZ0KB07ZDNW1YR3K9HZ989W      success           0000
# 1      01GZZ87X94P72JDH4MCXBVQVDN      success           0000
# 2      01GZZ8E62F89YKEH23QCPV5ZHR      success           0000
# 3      01GZZ9SMEFX7KBC5Z3C34SYZDW      success           0000
# 4      01H01G3T5JKRVK18MJJVV6AQFE      success           0000
# ...                           ...          ...            ...
# 25304  01JV4NJP3M2M5DFG1PQ1B0E8V6      success        SUCCESS
# 25305  01JV4P5BVENDHYQ2SB9Y31VPE9      success        SUCCESS
# 25306  01JV6B299Z91ZF1FZVV93Q5JW7      success        SUCCESS
# 25307  01JV6BAA6R7036CJ0V6Q8FTZPA      success        SUCCESS
# 25308  01JV6DBGK4VDKS753RWAQZEMBR      success        SUCCESS
#
#       providerPaymentName
# 0                    kicc
# 1                    kicc
# 2                    kicc
# 3                    kicc
# 4                    kicc
# ...                   ...
# 25304                kicc
# 25305                kicc
# 25306                kicc
# 25307                kicc
# 25308                kicc
#
# [25309 rows x 7 columns]
