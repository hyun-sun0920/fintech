# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
data=pd.read_csv("https://raw.githubusercontent.com/haram4th/ablearn/main/advertising.csv")
data.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                     68.95   NaN     61833.90                256.09
# 1                     80.23  31.0     68441.85                193.77
# 2                     69.47  26.0     59785.94                236.50
# 3                     74.15  29.0     54806.18                245.89
# 4                     68.37  35.0     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#          Timestamp  Clicked on Ad
# 0   3/27/2016 0:53              0
# 1    4/4/2016 1:39              0
# 2  3/13/2016 20:35              0
# 3   1/10/2016 2:31              0
# 4    6/3/2016 3:36              0

# %%
data.describe()
# Out:
#        Daily Time Spent on Site         Age   Area Income  \
# count               1000.000000  916.000000   1000.000000
# mean                  65.000200   36.128821  55000.000080
# std                   15.853615    9.018548  13414.634022
# min                   32.600000   19.000000  13996.500000
# 25%                   51.360000   29.000000  47031.802500
# 50%                   68.215000   35.000000  57012.300000
# 75%                   78.547500   42.000000  65470.635000
# max                   91.430000   61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# 75%              218.792500     1.000000        1.00000
# max              269.960000     1.000000        1.00000

# %%
data.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# Daily Time Spent on Site     0
# Age                         84
# Area Income                  0
# Daily Internet Usage         0
# Ad Topic Line                0
# City                         0
# Male                         0
# Country                      0
# Timestamp                    0
# Clicked on Ad                0
# dtype: int64

# %%
data['Age'].value_counts()
# Out:
# Age
# 31.0    53
# 28.0    45
# 29.0    42
# 36.0    40
# 33.0    37
# 26.0    37
# 30.0    35
# 34.0    35
# 32.0    35
# 40.0    34
# 35.0    33
# 27.0    33
# 37.0    32
# 41.0    29
# 45.0    29
# 38.0    28
# 25.0    27
# 39.0    26
# 42.0    25
# 43.0    21
# 50.0    20
# 23.0    19
# 24.0    19
# 44.0    19
# 46.0    18
# 49.0    17
# 48.0    15
# 52.0    15
# 47.0    13
# 51.0    12
# 22.0    11
# 53.0    10
# 54.0     9
# 55.0     7
# 20.0     6
# 57.0     6
# 19.0     6
# 21.0     5
# 60.0     4
# 58.0     4
# 56.0     2
# 59.0     2
# 61.0     1
# Name: count, dtype: int64

# %%
data['Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 916 non-null    float64
# dtypes: float64(1)
# memory usage: 7.9 KB

# %%
data['Age'].describe()
# Out:
# count    916.000000
# mean      36.128821
# std        9.018548
# min       19.000000
# 25%       29.000000
# 50%       35.000000
# 75%       42.000000
# max       61.000000
# Name: Age, dtype: float64

# %%
len(data['Age'])
# Out:
# 1000

# %%
len(data)
# Out:
# 1000

# %%
data['Age'].isna().sum()/len(data) * 100
# Out:
# np.float64(8.4)

# %%
data['Age'].mean()
# Out:
# np.float64(36.12882096069869)

# %%
data['Age']=data['Age'].fillna(data['Age'].mean())

# %%
data.isna().sum()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Ad Topic Line               0
# City                        0
# Male                        0
# Country                     0
# Timestamp                   0
# Clicked on Ad               0
# dtype: int64

# %%
num_cols=data[['Daily Time Spent on Site', 'Age', 'Area Income',
       'Daily Internet Usage']]
cat_cols=data[['Ad Topic Line', 'City', 'Male', 'Country',
       'Timestamp','Clicked on Ad']]

# %%
for col in num_cols:
    print("="*25, col, "="*25)
    sns.histplot(data[col])
    plt.show()
    print()
# Out:
# ========================= Daily Time Spent on Site =========================
# ========================= Age =========================
# ========================= Area Income =========================
# ========================= Daily Internet Usage =========================

# %%
data['Ad Topic Line'].value_counts()
# Out:
# Ad Topic Line
# Virtual 5thgeneration emulation                  1
# Cloned 5thgeneration orchestration               1
# Monitored national standardization               1
# Organic bottom-line service-desk                 1
# Triple-buffered reciprocal time-frame            1
#                                                 ..
# Team-oriented grid-enabled Local Area Network    1
# Centralized content-based focus group            1
# Synergistic fresh-thinking array                 1
# Grass-roots coherent extranet                    1
# Persistent demand-driven interface               1
# Name: count, Length: 1000, dtype: int64

# %%
data['City'].value_counts()
# Out:
# City
# Lisamouth        3
# Williamsport     3
# West Amanda      2
# East Timothy     2
# Lake Patrick     2
#                 ..
# Nicholasland     1
# Duffystad        1
# New Darlene      1
# South Jessica    1
# Collinsburgh     1
# Name: count, Length: 969, dtype: int64

# %%
data['Country'].value_counts()
# Out:
# Country
# Czech Republic      9
# France              9
# Senegal             8
# Peru                8
# Greece              8
#                    ..
# Kiribati            1
# Marshall Islands    1
# Bermuda             1
# Mozambique          1
# Lesotho             1
# Name: count, Length: 237, dtype: int64

# %%
data['Timestamp'].value_counts()
# Out:
# Timestamp
# 5/20/2016 12:17    2
# 5/26/2016 15:40    2
# 5/30/2016 8:02     2
# 2/24/2016 4:11     1
# 4/7/2016 15:18     1
#                   ..
# 2/11/2016 21:49    1
# 4/22/2016 2:07     1
# 2/1/2016 17:24     1
# 3/24/2016 2:35     1
# 1/10/2016 2:31     1
# Name: count, Length: 997, dtype: int64

# %%
data[['City', 'Clicked on Ad']].groupby('City').count()
# Out:
#                Clicked on Ad
# City
# Adamsbury                  1
# Adamside                   1
# Adamsstad                  1
# Alanview                   1
# Alexanderfurt              1
# ...                      ...
# Youngburgh                 1
# Youngfort                  1
# Yuton                      1
# Zacharystad                1
# Zacharyton                 1
#
# [969 rows x 1 columns]

# %%
data[['Country', 'Clicked on Ad']].groupby('Country').count()
# Out:
#                    Clicked on Ad
# Country
# Afghanistan                    8
# Albania                        7
# Algeria                        6
# American Samoa                 5
# Andorra                        2
# ...                          ...
# Wallis and Futuna              4
# Western Sahara                 7
# Yemen                          3
# Zambia                         4
# Zimbabwe                       6
#
# [237 rows x 1 columns]

# %%
data[['Timestamp', 'Clicked on Ad']].groupby('Timestamp').count()
# Out:
#                 Clicked on Ad
# Timestamp
# 1/1/2016 15:14              1
# 1/1/2016 20:17              1
# 1/1/2016 21:58              1
# 1/1/2016 2:52               1
# 1/1/2016 3:35               1
# ...                       ...
# 7/8/2016 3:47               1
# 7/9/2016 11:04              1
# 7/9/2016 11:18              1
# 7/9/2016 14:55              1
# 7/9/2016 16:23              1
#
# [997 rows x 1 columns]

# %%
data['Timestamp']
# Out:
# 0       3/27/2016 0:53
# 1        4/4/2016 1:39
# 2      3/13/2016 20:35
# 3       1/10/2016 2:31
# 4        6/3/2016 3:36
#             ...
# 995    2/11/2016 21:49
# 996     4/22/2016 2:07
# 997     2/1/2016 17:24
# 998     3/24/2016 2:35
# 999     6/3/2016 21:43
# Name: Timestamp, Length: 1000, dtype: object

# %%
data['Timestamp']=pd.to_datetime(data['Timestamp'])

# %%
data['Date']=data['Timestamp'].dt.date

# %%
data['Date']
# Out:
# 0      2016-03-27
# 1      2016-04-04
# 2      2016-03-13
# 3      2016-01-10
# 4      2016-06-03
#           ...
# 995    2016-02-11
# 996    2016-04-22
# 997    2016-02-01
# 998    2016-03-24
# 999    2016-06-03
# Name: Date, Length: 1000, dtype: object

# %%
data['Time']=data['Timestamp'].dt.time

# %%
data['Time']
# Out:
# 0      00:53:00
# 1      01:39:00
# 2      20:35:00
# 3      02:31:00
# 4      03:36:00
#          ...
# 995    21:49:00
# 996    02:07:00
# 997    17:24:00
# 998    02:35:00
# 999    21:43:00
# Name: Time, Length: 1000, dtype: object

# %%
data[['Date', 'Clicked on Ad']].groupby('Date').count()
# Out:
#             Clicked on Ad
# Date
# 2016-01-01              7
# 2016-01-02              4
# 2016-01-03              8
# 2016-01-04              6
# 2016-01-05             11
# ...                   ...
# 2016-07-20              5
# 2016-07-21              6
# 2016-07-22              2
# 2016-07-23              6
# 2016-07-24              1
#
# [203 rows x 1 columns]

# %%
data['Month'] = data['Timestamp'].dt.month

# %%
data[['Month', 'Clicked on Ad']].groupby('Month').count()
# Out:
#        Clicked on Ad
# Month
# 1                147
# 2                160
# 3                156
# 4                147
# 5                147
# 6                142
# 7                101

# %%
data['Time'] = data['Timestamp'].dt.time

# %%
data[['Time', 'Clicked on Ad']].groupby('Time').count()
# Out:
#           Clicked on Ad
# Time
# 00:00:00              1
# 00:01:00              3
# 00:02:00              2
# 00:05:00              2
# 00:06:00              1
# ...                 ...
# 23:47:00              2
# 23:48:00              1
# 23:54:00              1
# 23:56:00              1
# 23:59:00              1
#
# [731 rows x 1 columns]

# %%
data['Time'].astype
# Out:
# <bound method NDFrame.astype of 0      00:53:00
# 1      01:39:00
# 2      20:35:00
# 3      02:31:00
# 4      03:36:00
#          ...
# 995    21:49:00
# 996    02:07:00
# 997    17:24:00
# 998    02:35:00
# 999    21:43:00
# Name: Time, Length: 1000, dtype: object>

# %%
data['Hour']=pd.to_datetime(data['Time'].astype(str)).dt.hour
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3212\1141980894.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Hour']=pd.to_datetime(data['Time'].astype(str)).dt.hour

# %%
data['Hour']
# Out:
# 0       0
# 1       1
# 2      20
# 3       2
# 4       3
#        ..
# 995    21
# 996     2
# 997    17
# 998     2
# 999    21
# Name: Hour, Length: 1000, dtype: int32

# %% [markdown]
# # 선생님 풀이

# %%
data['Age']=data['Age'].fillna(data['Age'].mean())

# %%
data.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.128821  55000.000080
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.750000  47031.802500
# 50%                   68.215000    36.000000  57012.300000
# 75%                   78.547500    41.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
# std                   15.853615     8.631066  13414.634022
#
#        Daily Internet Usage         Male                   Timestamp  \
# count           1000.000000  1000.000000                        1000
# mean             180.000100     0.481000  2016-04-10 10:33:36.840000
# min              104.780000     0.000000         2016-01-01 02:52:00
# 25%              138.830000     0.000000         2016-02-18 02:55:15
# 50%              183.130000     0.000000         2016-04-07 17:27:00
# 75%              218.792500     1.000000         2016-05-31 03:18:00
# max              269.960000     1.000000         2016-07-24 00:22:00
# std               43.902339     0.499889                         NaN
#
#        Clicked on Ad        Month         Hour
# count     1000.00000  1000.000000  1000.000000
# mean         0.50000     3.817000    11.660000
# min          0.00000     1.000000     0.000000
# 25%          0.00000     2.000000     6.000000
# 50%          0.50000     4.000000    12.000000
# 75%          1.00000     5.000000    18.000000
# max          1.00000     7.000000    23.000000
# std          0.50025     1.926973     6.960952

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
new_data=data.drop(['Area income','Daily Internet Usage'], axis=1)
sns.boxplot(new_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 new_data=data.drop(['Area income','Daily Internet Usage'], axis=1)
#       2 sns.boxplot(new_data)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Area income'] not found in axis"

# %%
num_cols=data[['Daily Time Spent on Site', 'Age', 'Area Income',
       'Daily Internet Usage']]
cat_cols=data[['Ad Topic Line', 'City', 'Male', 'Country']]

# %%
for col in cat_cols:
    print("="*20, col, "="*20)
    print(f"{col} n_unique: {cat_cols[col].nunique()}")
    print(cat_cols[col].value_counts())
    print(data.groupby(col)['Clicked on Ad'].mean().sort_values(ascending=False))
# Out:
# ==================== Ad Topic Line ====================
# Ad Topic Line n_unique: 1000
# Ad Topic Line
# Virtual 5thgeneration emulation                  1
# Cloned 5thgeneration orchestration               1
# Monitored national standardization               1
# Organic bottom-line service-desk                 1
# Triple-buffered reciprocal time-frame            1
#                                                 ..
# Team-oriented grid-enabled Local Area Network    1
# Centralized content-based focus group            1
# Synergistic fresh-thinking array                 1
# Grass-roots coherent extranet                    1
# Persistent demand-driven interface               1
# Name: count, Length: 1000, dtype: int64
# Ad Topic Line
# Visionary mission-critical application      1.0
# Visionary maximized process improvement     1.0
# Adaptive asynchronous attitude              1.0
# Adaptive context-sensitive application      1.0
# Adaptive contextually-based methodology     1.0
#                                            ...
# Vision-oriented human-resource synergy      0.0
# Vision-oriented multi-tasking success       0.0
# Vision-oriented next generation solution    0.0
# Vision-oriented real-time framework         0.0
# Vision-oriented uniform knowledgebase       0.0
# Name: Clicked on Ad, Length: 1000, dtype: float64
# ==================== City ====================
# City n_unique: 969
# City
# Lisamouth        3
# Williamsport     3
# West Amanda      2
# East Timothy     2
# Lake Patrick     2
#                 ..
# Nicholasland     1
# Duffystad        1
# New Darlene      1
# South Jessica    1
# Collinsburgh     1
# Name: count, Length: 969, dtype: int64
# City
# Zacharyton         1.0
# Adamsbury          1.0
# Adamside           1.0
# Yuton              1.0
# Youngfort          1.0
#                   ...
# West Angela        0.0
# West Angelabury    0.0
# West Arielstad     0.0
# West Barbara       0.0
# Adamsstad          0.0
# Name: Clicked on Ad, Length: 969, dtype: float64
# ==================== Male ====================
# Male n_unique: 2
# Male
# 0    519
# 1    481
# Name: count, dtype: int64
# Male
# 0    0.518304
# 1    0.480249
# Name: Clicked on Ad, dtype: float64
# ==================== Country ====================
# Country n_unique: 237
# Country
# Czech Republic      9
# France              9
# Senegal             8
# Peru                8
# Greece              8
#                    ..
# Kiribati            1
# Marshall Islands    1
# Bermuda             1
# Mozambique          1
# Lesotho             1
# Name: count, Length: 237, dtype: int64
# Country
# Andorra                                                1.0
# British Indian Ocean Territory (Chagos Archipelago)    1.0
# Ethiopia                                               1.0
# Germany                                                1.0
# Montserrat                                             1.0
#                                                       ...
# Niue                                                   0.0
# Swaziland                                              0.0
# Sudan                                                  0.0
# Sri Lanka                                              0.0
# Slovakia (Slovak Republic)                             0.0
# Name: Clicked on Ad, Length: 237, dtype: float64

# %%
for col in num_cols:
    print("="*20, col, "="*20)
    sns.histplot(num_cols[col])
    plt.show()
    sns.boxplot(num_cols[col])
    plt.show()
# Out:
# ==================== Daily Time Spent on Site ====================
# ==================== Age ====================
# ==================== Area Income ====================
# ==================== Daily Internet Usage ====================

# %%
data.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad', 'Date', 'Time', 'Month', 'Hour'],
#       dtype='object')

# %%
sns.histplot(x='Daily Time Spent on Site', hue='Clicked on Ad', data=data)
# Out:
# <Axes: xlabel='Daily Time Spent on Site', ylabel='Count'>

# %%
sns.histplot(x='Daily Internet Usage', hue='Clicked on Ad', data=data)
# Out:
# <Axes: xlabel='Daily Internet Usage', ylabel='Count'>

# %%
sns.histplot(x='Age', hue='Clicked on Ad', data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(x='Area Income', hue='Clicked on Ad', data=data)
# Out:
# <Axes: xlabel='Area Income', ylabel='Count'>

# %%
data.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad', 'Date', 'Time', 'Month', 'Hour'],
#       dtype='object')

# %%
data=data.drop(['Ad Topic Line', 'City','Country','Timestamp'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 data=data.drop(['Ad Topic Line', 'City','Country','Timestamp'], axis=1)
#       2 data=data.drop(['Date','Time'], axis=1)
#       3 data
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Ad Topic Line', 'City', 'Country', 'Timestamp'] not found in axis"

# %%
data=data.drop(['Date','Time'], axis=1)
data
# Out:
#      Daily Time Spent on Site        Age  Area Income  Daily Internet Usage  \
# 0                       68.95  36.128821     61833.90                256.09
# 1                       80.23  31.000000     68441.85                193.77
# 2                       69.47  26.000000     59785.94                236.50
# 3                       74.15  29.000000     54806.18                245.89
# 4                       68.37  35.000000     73889.99                225.58
# ..                        ...        ...          ...                   ...
# 995                     72.97  30.000000     71384.57                208.58
# 996                     51.30  45.000000     67782.17                134.42
# 997                     51.63  51.000000     42415.72                120.37
# 998                     55.55  19.000000     41920.79                187.95
# 999                     45.01  26.000000     29875.80                178.35
#
#      Male  Clicked on Ad  Month  Hour
# 0       0              0      3     0
# 1       1              0      4     1
# 2       0              0      3    20
# 3       1              0      1     2
# 4       0              0      6     3
# ..    ...            ...    ...   ...
# 995     1              1      2    21
# 996     1              1      4     2
# 997     1              1      2    17
# 998     0              0      3     2
# 999     0              1      6    21
#
# [1000 rows x 8 columns]

# %%
data.corr(method='spearman')
# Out:
#                           Daily Time Spent on Site       Age  Area Income  \
# Daily Time Spent on Site                  1.000000 -0.314454     0.283134
# Age                                      -0.314454  1.000000    -0.140395
# Area Income                               0.283134 -0.140395     1.000000
# Daily Internet Usage                      0.514108 -0.365474     0.339160
# Male                                     -0.015922 -0.016850    -0.014369
# Clicked on Ad                            -0.744873  0.475414    -0.467224
# Month                                    -0.010500  0.038068    -0.039107
# Hour                                     -0.003654 -0.055167     0.032277
#
#                           Daily Internet Usage      Male  Clicked on Ad  \
# Daily Time Spent on Site              0.514108 -0.015922      -0.744873
# Age                                  -0.365474 -0.016850       0.475414
# Area Income                           0.339160 -0.014369      -0.467224
# Daily Internet Usage                  1.000000  0.028204      -0.776607
# Male                                  0.028204  1.000000      -0.038027
# Clicked on Ad                        -0.776607 -0.038027       1.000000
# Month                                 0.018197  0.006364       0.016549
# Hour                                  0.075639  0.057844      -0.047751
#
#                              Month      Hour
# Daily Time Spent on Site -0.010500 -0.003654
# Age                       0.038068 -0.055167
# Area Income              -0.039107  0.032277
# Daily Internet Usage      0.018197  0.075639
# Male                      0.006364  0.057844
# Clicked on Ad             0.016549 -0.047751
# Month                     1.000000 -0.013188
# Hour                     -0.013188  1.000000

# %%
sns.heatmap(data.corr(method='spearman'), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # 나이브베이즈를 이용해서 분류분석하기
# * 독립변수가 수치형으로 이루어진 경우: GaussianNB
# * 문자가 많은 경우: MultinominalNB

# %%
X=data.drop("Click on Ad", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 X=data.drop("Click on Ad", axis=1)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Click on Ad'] not found in axis"

# %%
y=data["Click on Ad"]

# %%
y.value_counts()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.3, random_state=10)

# %%
# 독립변수에 수치형 자료가 많으므로 GaussianNB를 이용해서 분석
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report

# %%
gnb=GaussianNB()
gnb.fit(X_train, y_train)
pred=gnb.predict(X_test)
print(classification_report(y_test, pred))
