# %% [markdown]
# # 지도학습_다중회귀분석_고객별연간지출액예측

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib
import statsmodels.api as sm

# %%
data=pd.read_csv("./data/ecommerce.csv")

# %%
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
data['Avatar'].value_counts()
# Out:
# Avatar
# Teal              7
# Cyan              7
# CadetBlue         7
# GreenYellow       7
# SlateBlue         7
#                  ..
# PaleGoldenRod     1
# Coral             1
# NavajoWhite       1
# PaleGreen         1
# LightSlateGray    1
# Name: count, Length: 138, dtype: int64

# %%
data['Avatar'].describe()
# Out:
# count      500
# unique     138
# top       Teal
# freq         7
# Name: Avatar, dtype: object

# %%
data.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
data['Avg. Session Length'].value_counts()
# Out:
# Avg. Session Length
# 33.715981    1
# 34.497268    1
# 31.926272    1
# 33.000915    1
# 34.305557    1
#             ..
# 32.903251    1
# 34.507551    1
# 33.029332    1
# 33.541231    1
# 32.335990    1
# Name: count, Length: 500, dtype: int64

# %%
data['Avg. Session Length'].describe()
# Out:
# count    500.000000
# mean      33.053194
# std        0.992563
# min       29.532429
# 25%       32.341822
# 50%       33.082008
# 75%       33.711985
# max       36.139662
# Name: Avg. Session Length, dtype: float64

# %%
data['Time on App'].describe()
# Out:
# count    500.000000
# mean      12.052488
# std        0.994216
# min        8.508152
# 25%       11.388153
# 50%       11.983231
# 75%       12.753850
# max       15.126994
# Name: Time on App, dtype: float64

# %%
data['Time on Website'].describe()
# Out:
# count    500.000000
# mean      37.060445
# std        1.010489
# min       33.913847
# 25%       36.349257
# 50%       37.069367
# 75%       37.716432
# max       40.005182
# Name: Time on Website, dtype: float64

# %%
data['Length of Membership'].describe()
# Out:
# count    500.000000
# mean       3.533462
# std        0.999278
# min        0.269901
# 25%        2.930450
# 50%        3.533975
# 75%        4.126502
# max        6.922689
# Name: Length of Membership, dtype: float64

# %%
data['Yearly Amount Spent'].describe()
# Out:
# count    500.000000
# mean     499.314038
# std       79.314782
# min      256.670582
# 25%      445.038277
# 50%      498.887875
# 75%      549.313828
# max      765.518462
# Name: Yearly Amount Spent, dtype: float64

# %% [markdown]
# # one-hot encoding

# %%
X=data.drop(['Email', 'Address', 'Avatar','Yearly Amount Spent'], axis=1)
y=data['Yearly Amount Spent']
# Out:
# <bound method IndexOpsMixin.value_counts of 0      587.951054
# 1      392.204933
# 2      487.547505
# 3      581.852344
# 4      599.406092
#           ...
# 495    573.847438
# 496    529.049004
# 497    551.620145
# 498    456.469510
# 499    497.778642
# Name: Yearly Amount Spent, Length: 500, dtype: float64>

# %%
y.describe()
# Out:
# count    500.000000
# mean     499.314038
# std       79.314782
# min      256.670582
# 25%      445.038277
# 50%      498.887875
# 75%      549.313828
# max      765.518462
# Name: Yearly Amount Spent, dtype: float64

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 500 entries, 0 to 499
# Series name: Yearly Amount Spent
# Non-Null Count  Dtype
# --------------  -----
# 500 non-null    float64
# dtypes: float64(1)
# memory usage: 4.0 KB

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_valid, y_train, y_valid= train_test_split(X, y, test_size=0.4, random_state=42)
X_valid, X_test, y_valid, y_test= train_test_split(X_valid, y_valid, test_size=0.4, random_state=42)

# %% [markdown]
# # 스케일링

# %%
from sklearn.preprocessing import StandardScaler

# %%
sds

# %%
X

# %%
y

# %%
X_with_const=sm.add_constant(X)
model=sm.OLS(y, X_with_const).fit()
y_pred=model.predict(X_with_const)

print(model.summary())

# %%
X2=data.drop(['Email', 'Address', 'Avatar','Yearly Amount Spent','Time on Website'], axis=1)
y=data['Yearly Amount Spent']

# %%
X2

# %%
X2_with_const=sm.add_constant(X2)
model=sm.OLS(y, X2_with_const).fit()
y_pred=model.predict(X2_with_const)

print(model.summary())

# %%
y=

# %%
ss=StandardScaler()

# %%
import statsmodels.api as sm
X_train_const=sm.add_constant(X_train)
X_test_const=sm

# %%
result['루트평균편차제곱_RMSE']=result['평균편차제곱_MSE'].apply(np.sqrt)
