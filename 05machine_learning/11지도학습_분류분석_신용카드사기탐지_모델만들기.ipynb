# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib
import seaborn as sns

# %%
data=pd.read_csv("./data/fraud.csv")
data.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city  ...      lat      long  \
# 0                561 Perry Cove  Moravian Falls  ...  36.0788  -81.1781
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1852394 entries, 0 to 1852393
# Data columns (total 22 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   trans_date_trans_time  object
#  1   cc_num                 int64
#  2   merchant               object
#  3   category               object
#  4   amt                    float64
#  5   first                  object
#  6   last                   object
#  7   gender                 object
#  8   street                 object
#  9   city                   object
#  10  state                  object
#  11  zip                    int64
#  12  lat                    float64
#  13  long                   float64
#  14  city_pop               int64
#  15  job                    object
#  16  dob                    object
#  17  trans_num              object
#  18  unix_time              int64
#  19  merch_lat              float64
#  20  merch_long             float64
# ...

# %%
# 결측치가 없음
data.isna().sum() / len(data)
# Out:
# trans_date_trans_time    0.0
# cc_num                   0.0
# merchant                 0.0
# category                 0.0
# amt                      0.0
# first                    0.0
# last                     0.0
# gender                   0.0
# street                   0.0
# city                     0.0
# state                    0.0
# zip                      0.0
# lat                      0.0
# long                     0.0
# city_pop                 0.0
# job                      0.0
# dob                      0.0
# trans_num                0.0
# unix_time                0.0
# merch_lat                0.0
# merch_long               0.0
# is_fraud                 0.0
# dtype: float64

# %%
# 중복되는 값 없음
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [trans_date_trans_time, cc_num, merchant, category, amt, first, last, gender, street, city, state, zip, lat, long, city_pop, job, dob, trans_num, unix_time, merch_lat, merch_long, is_fraud]
# Index: []
#
# [0 rows x 22 columns]

# %%
data.describe()
# Out:
#              cc_num           amt           zip           lat          long  \
# count  1.852394e+06  1.852394e+06  1.852394e+06  1.852394e+06  1.852394e+06
# mean   4.173860e+17  7.006357e+01  4.881326e+04  3.853931e+01 -9.022783e+01
# std    1.309115e+18  1.592540e+02  2.688185e+04  5.071470e+00  1.374789e+01
# min    6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01 -1.656723e+02
# 25%    1.800429e+14  9.640000e+00  2.623700e+04  3.466890e+01 -9.679800e+01
# 50%    3.521417e+15  4.745000e+01  4.817400e+04  3.935430e+01 -8.747690e+01
# 75%    4.642255e+15  8.310000e+01  7.204200e+04  4.194040e+01 -8.015800e+01
# max    4.992346e+18  2.894890e+04  9.992100e+04  6.669330e+01 -6.795030e+01
#
#            city_pop     unix_time     merch_lat    merch_long      is_fraud
# count  1.852394e+06  1.852394e+06  1.852394e+06  1.852394e+06  1.852394e+06
# mean   8.864367e+04  1.358674e+09  3.853898e+01 -9.022794e+01  5.210015e-03
# ...

# %%
data.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat',
#        'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud'],
#       dtype='object')

# %%
data['trans_date_trans_time'].value_counts()
# Out:
# trans_date_trans_time
# 2019-04-22 16:02:01    4
# 2020-06-01 01:37:47    4
# 2020-06-02 12:47:07    4
# 2020-10-05 19:37:49    4
# 2020-12-13 17:53:47    4
#                       ..
# 2019-01-01 00:41:45    1
# 2019-01-01 00:42:26    1
# 2019-01-01 00:43:38    1
# 2019-01-01 00:44:20    1
# 2020-12-31 23:50:17    1
# Name: count, Length: 1819551, dtype: int64

# %%
data['trans_date_trans_time'].describe()
# Out:
# count                 1852394
# unique                1819551
# top       2019-04-22 16:02:01
# freq                        4
# Name: trans_date_trans_time, dtype: object

# %%
data['cc_num'].value_counts()
# Out:
# cc_num
# 6538441737335434       4392
# 30270432095985         4392
# 4642255475285942       4386
# 6538891242532018       4386
# 4364010865167176       4386
#                        ...
# 4352307151555405069       7
# 501894933032              7
# 4975457191020             7
# 6577777028615915          7
# 4295296907373             6
# Name: count, Length: 999, dtype: int64

# %%
data['cc_num'].describe()
# Out:
# count    1.852394e+06
# mean     4.173860e+17
# std      1.309115e+18
# min      6.041621e+10
# 25%      1.800429e+14
# 50%      3.521417e+15
# 75%      4.642255e+15
# max      4.992346e+18
# Name: cc_num, dtype: float64

# %%
data['merchant'].value_counts()
# Out:
# merchant
# fraud_Kilback LLC                        6262
# fraud_Cormier LLC                        5246
# fraud_Schumm PLC                         5195
# fraud_Kuhn LLC                           5031
# fraud_Boyer PLC                          4999
#                                          ...
# fraud_Douglas, DuBuque and McKenzie      1101
# fraud_Treutel-King                       1098
# fraud_Satterfield-Lowe                   1095
# fraud_Hahn, Douglas and Schowalter       1091
# fraud_Ritchie, Bradtke and Stiedemann    1090
# Name: count, Length: 693, dtype: int64

# %%
data['merchant'].describe()
# Out:
# count               1852394
# unique                  693
# top       fraud_Kilback LLC
# freq                   6262
# Name: merchant, dtype: object

# %%
data['category'].value_counts()
# Out:
# category
# gas_transport     188029
# grocery_pos       176191
# home              175460
# shopping_pos      166463
# kids_pets         161727
# shopping_net      139322
# entertainment     134118
# food_dining       130729
# personal_care     130085
# health_fitness    122553
# misc_pos          114229
# misc_net           90654
# grocery_net        64878
# travel             57956
# Name: count, dtype: int64

# %%
data['category'].describe()
# Out:
# count           1852394
# unique               14
# top       gas_transport
# freq             188029
# Name: category, dtype: object

# %%
data['amt'].value_counts()
# Out:
# amt
# 1.14       779
# 1.10       745
# 1.04       744
# 1.08       741
# 1.20       737
#           ...
# 355.69       1
# 336.13       1
# 647.89       1
# 1258.29      1
# 654.38       1
# Name: count, Length: 60616, dtype: int64

# %%
data['amt'].describe()
# Out:
# count    1.852394e+06
# mean     7.006357e+01
# std      1.592540e+02
# min      1.000000e+00
# 25%      9.640000e+00
# 50%      4.745000e+01
# 75%      8.310000e+01
# max      2.894890e+04
# Name: amt, dtype: float64

# %%
data['first'].value_counts()
# Out:
# first
# Christopher    38112
# Robert         30743
# Jessica        29236
# David          28564
# Michael        28539
#                ...
# Nicole             9
# Phyllis            8
# Molly              8
# Angelica           7
# Samantha           7
# Name: count, Length: 355, dtype: int64

# %%
data['first'].describe()
# Out:
# count         1852394
# unique            355
# top       Christopher
# freq            38112
# Name: first, dtype: object

# %%
data['name']=data['first']+data['last']

# %%
data.drop(['first','last'], axis=1)
# Out:
#         trans_date_trans_time            cc_num  \
# 0         2019-01-01 00:00:18  2703186189652095
# 1         2019-01-01 00:00:44      630423337322
# 2         2019-01-01 00:00:51    38859492057661
# 3         2019-01-01 00:01:16  3534093764340240
# 4         2019-01-01 00:03:06   375534208663984
# ...                       ...               ...
# 1852389   2020-12-31 23:59:07    30560609640617
# 1852390   2020-12-31 23:59:09  3556613125071656
# 1852391   2020-12-31 23:59:15  6011724471098086
# 1852392   2020-12-31 23:59:24     4079773899158
# 1852393   2020-12-31 23:59:34  4170689372027579
#
#                                    merchant        category     amt gender  \
# 0                fraud_Rippin, Kub and Mann        misc_net    4.97      F
# 1           fraud_Heller, Gutmann and Zieme     grocery_pos  107.23      F
# 2                      fraud_Lind-Buckridge   entertainment  220.11      M
# 3        fraud_Kutch, Hermiston and Farrell   gas_transport   45.00      M
# ...

# %%
data
# Out:
#         trans_date_trans_time            cc_num  \
# 0         2019-01-01 00:00:18  2703186189652095
# 1         2019-01-01 00:00:44      630423337322
# 2         2019-01-01 00:00:51    38859492057661
# 3         2019-01-01 00:01:16  3534093764340240
# 4         2019-01-01 00:03:06   375534208663984
# ...                       ...               ...
# 1852389   2020-12-31 23:59:07    30560609640617
# 1852390   2020-12-31 23:59:09  3556613125071656
# 1852391   2020-12-31 23:59:15  6011724471098086
# 1852392   2020-12-31 23:59:24     4079773899158
# 1852393   2020-12-31 23:59:34  4170689372027579
#
#                                    merchant        category     amt  \
# 0                fraud_Rippin, Kub and Mann        misc_net    4.97
# 1           fraud_Heller, Gutmann and Zieme     grocery_pos  107.23
# 2                      fraud_Lind-Buckridge   entertainment  220.11
# 3        fraud_Kutch, Hermiston and Farrell   gas_transport   45.00
# ...

# %%
data['gender'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          F
# 1          F
# 2          M
# 3          M
# 4          M
#           ..
# 1852389    M
# 1852390    M
# 1852391    F
# 1852392    M
# 1852393    M
# Name: gender, Length: 1852394, dtype: object>

# %%
data['gender'].describe()
# Out:
# count     1852394
# unique          2
# top             F
# freq      1014749
# Name: gender, dtype: object

# %%
data['address']=data['street']+data['city']+data['state']
data.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city  ... city_pop  \
# 0                561 Perry Cove  Moravian Falls  ...     3495
# ...

# %%
data.drop(['street','city', 'state'], axis=1)
# Out:
#         trans_date_trans_time            cc_num  \
# 0         2019-01-01 00:00:18  2703186189652095
# 1         2019-01-01 00:00:44      630423337322
# 2         2019-01-01 00:00:51    38859492057661
# 3         2019-01-01 00:01:16  3534093764340240
# 4         2019-01-01 00:03:06   375534208663984
# ...                       ...               ...
# 1852389   2020-12-31 23:59:07    30560609640617
# 1852390   2020-12-31 23:59:09  3556613125071656
# 1852391   2020-12-31 23:59:15  6011724471098086
# 1852392   2020-12-31 23:59:24     4079773899158
# 1852393   2020-12-31 23:59:34  4170689372027579
#
#                                    merchant        category     amt  \
# 0                fraud_Rippin, Kub and Mann        misc_net    4.97
# 1           fraud_Heller, Gutmann and Zieme     grocery_pos  107.23
# 2                      fraud_Lind-Buckridge   entertainment  220.11
# 3        fraud_Kutch, Hermiston and Farrell   gas_transport   45.00
# ...

# %%
data['zip'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1852394 entries, 0 to 1852393
# Series name: zip
# Non-Null Count    Dtype
# --------------    -----
# 1852394 non-null  int64
# dtypes: int64(1)
# memory usage: 14.1 MB

# %%
data[['zip','address']].groupby('zip').count()
# Out:
#        address
# zip
# 1257      2923
# 1330      1466
# 1535       734
# 1545      1468
# 1612       738
# ...        ...
# 99323     3651
# 99746      734
# 99747       12
# 99783     2203
# 99921       14
#
# [985 rows x 1 columns]

# %%
data.loc[data['zip'] == 1257, ['zip', 'address']]
# Out:
#           zip                                   address
# 1514     1257  58665 Nicholas Ford Suite 348SheffieldMA
# 2491     1257  58665 Nicholas Ford Suite 348SheffieldMA
# 4762     1257  58665 Nicholas Ford Suite 348SheffieldMA
# 6043     1257  58665 Nicholas Ford Suite 348SheffieldMA
# 6499     1257  58665 Nicholas Ford Suite 348SheffieldMA
# ...       ...                                       ...
# 1849080  1257  58665 Nicholas Ford Suite 348SheffieldMA
# 1849220  1257  58665 Nicholas Ford Suite 348SheffieldMA
# 1850964  1257  58665 Nicholas Ford Suite 348SheffieldMA
# 1850981  1257  58665 Nicholas Ford Suite 348SheffieldMA
# 1851941  1257  58665 Nicholas Ford Suite 348SheffieldMA
#
# [2923 rows x 2 columns]

# %%
data.loc[data['zip'] == 1330, ['zip', 'address']]
# Out:
#           zip                      address
# 322      1330  78652 Scott PortsAshfieldMA
# 2443     1330  78652 Scott PortsAshfieldMA
# 2928     1330  78652 Scott PortsAshfieldMA
# 2931     1330  78652 Scott PortsAshfieldMA
# 4687     1330  78652 Scott PortsAshfieldMA
# ...       ...                          ...
# 1844621  1330  78652 Scott PortsAshfieldMA
# 1845179  1330  78652 Scott PortsAshfieldMA
# 1845621  1330  78652 Scott PortsAshfieldMA
# 1849644  1330  78652 Scott PortsAshfieldMA
# 1852067  1330  78652 Scott PortsAshfieldMA
#
# [1466 rows x 2 columns]

# %%
data.loc[data['zip'] == 1535, ['zip', 'address']]
# Out:
#           zip                                        address
# 3535     1535  06730 Joshua Isle Suite 555North BrookfieldMA
# 4233     1535  06730 Joshua Isle Suite 555North BrookfieldMA
# 8898     1535  06730 Joshua Isle Suite 555North BrookfieldMA
# 10474    1535  06730 Joshua Isle Suite 555North BrookfieldMA
# 16128    1535  06730 Joshua Isle Suite 555North BrookfieldMA
# ...       ...                                            ...
# 1835183  1535  06730 Joshua Isle Suite 555North BrookfieldMA
# 1844911  1535  06730 Joshua Isle Suite 555North BrookfieldMA
# 1851492  1535  06730 Joshua Isle Suite 555North BrookfieldMA
# 1851505  1535  06730 Joshua Isle Suite 555North BrookfieldMA
# 1852240  1535  06730 Joshua Isle Suite 555North BrookfieldMA
#
# [734 rows x 2 columns]

# %%
data=data.drop(['address','street','city','state'], axis=1)

# %%
data
# Out:
#         trans_date_trans_time            cc_num  \
# 0         2019-01-01 00:00:18  2703186189652095
# 1         2019-01-01 00:00:44      630423337322
# 2         2019-01-01 00:00:51    38859492057661
# 3         2019-01-01 00:01:16  3534093764340240
# 4         2019-01-01 00:03:06   375534208663984
# ...                       ...               ...
# 1852389   2020-12-31 23:59:07    30560609640617
# 1852390   2020-12-31 23:59:09  3556613125071656
# 1852391   2020-12-31 23:59:15  6011724471098086
# 1852392   2020-12-31 23:59:24     4079773899158
# 1852393   2020-12-31 23:59:34  4170689372027579
#
#                                    merchant        category     amt  \
# 0                fraud_Rippin, Kub and Mann        misc_net    4.97
# 1           fraud_Heller, Gutmann and Zieme     grocery_pos  107.23
# 2                      fraud_Lind-Buckridge   entertainment  220.11
# 3        fraud_Kutch, Hermiston and Farrell   gas_transport   45.00
# ...

# %%
data[['zip','lat','long']].groupby('zip').count()
# Out:
#         lat  long
# zip
# 1257   2923  2923
# 1330   1466  1466
# 1535    734   734
# 1545   1468  1468
# 1612    738   738
# ...     ...   ...
# 99323  3651  3651
# 99746   734   734
# 99747    12    12
# 99783  2203  2203
# 99921    14    14
#
# [985 rows x 2 columns]

# %%
data.loc[data['zip']==1257,['zip','lat','long']]
# Out:
#           zip      lat     long
# 1514     1257  42.1001 -73.3611
# 2491     1257  42.1001 -73.3611
# 4762     1257  42.1001 -73.3611
# 6043     1257  42.1001 -73.3611
# 6499     1257  42.1001 -73.3611
# ...       ...      ...      ...
# 1849080  1257  42.1001 -73.3611
# 1849220  1257  42.1001 -73.3611
# 1850964  1257  42.1001 -73.3611
# 1850981  1257  42.1001 -73.3611
# 1851941  1257  42.1001 -73.3611
#
# [2923 rows x 3 columns]

# %%
data.loc[data['zip']==1330,['zip','lat','long']]
# Out:
#           zip      lat    long
# 322      1330  42.5232 -72.811
# 2443     1330  42.5232 -72.811
# 2928     1330  42.5232 -72.811
# 2931     1330  42.5232 -72.811
# 4687     1330  42.5232 -72.811
# ...       ...      ...     ...
# 1844621  1330  42.5232 -72.811
# 1845179  1330  42.5232 -72.811
# 1845621  1330  42.5232 -72.811
# 1849644  1330  42.5232 -72.811
# 1852067  1330  42.5232 -72.811
#
# [1466 rows x 3 columns]

# %%
data=data.drop(['lat','long'], axis=1)

# %%
data.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender    zip  city_pop  \
# 0       misc_net    4.97   Jennifer    Banks      F  28654      3495
# 1    grocery_pos  107.23  Stephanie     Gill      F  99160       149
# 2  entertainment  220.11     Edward  Sanchez      M  83252      4154
# 3  gas_transport   45.00     Jeremy    White      M  59632      1939
# 4       misc_pos   41.96      Tyler   Garcia      M  24433        99
#
#                                  job         dob  \
# ...

# %%
data['city_pop'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1852394 entries, 0 to 1852393
# Series name: city_pop
# Non-Null Count    Dtype
# --------------    -----
# 1852394 non-null  int64
# dtypes: int64(1)
# memory usage: 14.1 MB

# %%
data['city_pop'].describe()
# Out:
# count    1.852394e+06
# mean     8.864367e+04
# std      3.014876e+05
# min      2.300000e+01
# 25%      7.410000e+02
# 50%      2.443000e+03
# 75%      2.032800e+04
# max      2.906700e+06
# Name: city_pop, dtype: float64

# %%
data['city_pop'].value_counts()
# Out:
# city_pop
# 606        8049
# 1595797    7312
# 1312922    7297
# 241        6578
# 1766       6556
#            ...
# 242803        7
# 1888          7
# 4046          7
# 20133         7
# 1071          6
# Name: count, Length: 891, dtype: int64

# %%
data['job'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1852394 entries, 0 to 1852393
# Series name: job
# Non-Null Count    Dtype
# --------------    -----
# 1852394 non-null  object
# dtypes: object(1)
# memory usage: 14.1+ MB

# %%
data['job'].value_counts()
# Out:
# job
# Film/video editor             13898
# Exhibition designer           13167
# Surveyor, land/geomatics      12436
# Naval architect               12434
# Materials engineer            11711
#                               ...
# Veterinary surgeon                8
# Engineer, water                   8
# Contracting civil engineer        7
# Ship broker                       7
# Warehouse manager                 7
# Name: count, Length: 497, dtype: int64

# %%
data['job'].describe()
# Out:
# count               1852394
# unique                  497
# top       Film/video editor
# freq                  13898
# Name: job, dtype: object

# %%
data['dob'].describe()
# Out:
# count        1852394
# unique           984
# top       1977-03-23
# freq            8044
# Name: dob, dtype: object

# %%
data['dob'].value_counts()
# Out:
# dob
# 1977-03-23    8044
# 1988-09-15    6574
# 1981-08-29    6571
# 1955-05-06    5121
# 1960-01-13    4395
#               ...
# 1962-03-14       7
# 1944-06-17       7
# 1970-06-25       7
# 1932-05-09       7
# 1998-08-02       6
# Name: count, Length: 984, dtype: int64

# %%
data[['name','dob']].groupby('name').count()
# Out:
#                   dob
# name
# AaronMurray      2920
# AaronPena        2191
# AaronRogers       741
# AaronStewart      737
# AdamKeller        743
# ...               ...
# WilliamThompson  2927
# WillieJordan     1463
# XavierBeltran    2197
# ZacharyAllen     2196
# ZacharyBoone      735
#
# [989 rows x 1 columns]

# %%
data['cc_num'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          2703186189652095
# 1              630423337322
# 2            38859492057661
# 3          3534093764340240
# 4           375534208663984
#                  ...
# 1852389      30560609640617
# 1852390    3556613125071656
# 1852391    6011724471098086
# 1852392       4079773899158
# 1852393    4170689372027579
# Name: cc_num, Length: 1852394, dtype: int64>

# %%
data['cc_num'].describe()
# Out:
# count    1.852394e+06
# mean     4.173860e+17
# std      1.309115e+18
# min      6.041621e+10
# 25%      1.800429e+14
# 50%      3.521417e+15
# 75%      4.642255e+15
# max      4.992346e+18
# Name: cc_num, dtype: float64

# %%
data['cc_num'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1852394 entries, 0 to 1852393
# Series name: cc_num
# Non-Null Count    Dtype
# --------------    -----
# 1852394 non-null  int64
# dtypes: int64(1)
# memory usage: 14.1 MB

# %% [markdown]
# # 금융사기란?(Financial Fraud)
# * 금융 거래에서 속이거나 기만해서 자산이나 돈을 획득하는 행위
# * 주요유형
#     * 신용카드 사기
#     * 피싱, 신분도용
#     * 보험 사기
#     * 자금세탁

# %% [markdown]
# # 금융 사기 대응법
# * 고객의 거래 패턴 분석, 비정상 거래 포착
# * 전문가 기반 규칙 - 전문가들의 경험에 의한 사기 탐지
# * 통계 기반 분석 - 수학적 모델, 통계학 기반 모델로 이상탐지
# * 머신러닝 기반 분석 - 대규모 데이터 학습, 전문가 기반, 통계 기반으로 찾지 못하는 사기도 탐지 가능

# %% [markdown]
# # 금융 사기 탐지의 어려움
# * 사기 확인이 피해자 불만 표현을 통해서 이루어지는 경우가 많음
# * 사기 거래 자체가 적음 -> 데이터 확보가 어려움
# * 데이터 부족으로 인해 성능이 좋은 모델 생성이 어려움
# * 가상 데이터를 인공적으로 생성해서 모델 생성에 활용

# %% [markdown]
# # 사기 방지와 고객 경험의 균형
# * 정당한 거래가 차단되어 고객에게 좋지 않은 사용 경험을 주는 경우
# * 엄격한 탐지 -> 사용자 불편 증가
# * 관대한 탐지 -> 사기율 상승
# * 적절한 타협이 필요
