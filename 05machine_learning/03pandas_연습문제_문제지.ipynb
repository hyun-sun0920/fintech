# %%
import pandas as pd

# %%
pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pd.read_csv()
#
# TypeError: read_csv() missing 1 required positional argument: 'filepath_or_buffer'

# %%
# dataframe
data = {'country': ['Belgium', 'France', 'Germany', 'Netherlands', 'United Kingdom'],
        'population': [11.3, 64.3, 81.3, 16.9, 64.9],
        'area': [30510, 671308, 357050, 41526, 244820],
        'capital': ['Brussels', 'Paris', 'Berlin', 'Amsterdam', 'London']}
countries = pd.DataFrame(data)
countries = countries.set_index('country') # 인덱스 지정
countries
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brussels
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Belgium to United Kingdom
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   population  5 non-null      float64
#  1   area        5 non-null      int64
#  2   capital     5 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 160.0+ bytes

# %% [markdown]
# ---
#
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인구밀도를 의미하는 `density` 칼럼을 추가하세요. (주의: 현재 'population' 칼럼은 100만 단위로 표기되어 있습니다)
#
# </div>

# %%
countries['density']=countries['population']*1000000 / countries['area']
countries
# Out:
#                 population    area    capital     density
# country
# Belgium               11.3   30510   Brussels  370.370370
# France                64.3  671308      Paris   95.783158
# Germany               81.3  357050     Berlin  227.699202
# Netherlands           16.9   41526  Amsterdam  406.973944
# United Kingdom        64.9  244820     London  265.092721

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인구밀도가 300을 초과하는 국가(country)의 수도(capital)과 인구(population)을 선택해주세요.
#
# </div>

# %%
countries.loc[countries['density']>300, ['capital','population']]
# Out:
#                capital  population
# country
# Belgium       Brussels        11.3
# Netherlands  Amsterdam        16.9

# %%
countries[countries['density']>300]['capital']['population']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'population'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 countries[countries['density']>300]['capital']['population']
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'population'

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'density_ratio' 칼럼을 추가해주세요. (density_ratio = 인구밀도/평균 인구밀도)
# </div>

# %%
countries['density'].mean()
# Out:
# np.float64(273.1838790074409)

# %%
countries['density_ratio']=countries['density'] / countries['density'].mean()
countries
# Out:
#                 population    area    capital     density  density_ratio
# country
# Belgium               11.3   30510   Brussels  370.370370       1.355755
# France                64.3  671308      Paris   95.783158       0.350618
# Germany               81.3  357050     Berlin  227.699202       0.833502
# Netherlands           16.9   41526  Amsterdam  406.973944       1.489744
# United Kingdom        64.9  244820     London  265.092721       0.970382

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 영국(United Kingdom)의 수도(capital)를 'Cambridge'로 변경해주세요.
# </div>

# %%
countries.loc['United Kingdom', 'capital']='Cambridge'
countries
# Out:
#                 population    area    capital     density  density_ratio
# country
# Belgium               11.3   30510   Brussels  370.370370       1.355755
# France                64.3  671308      Paris   95.783158       0.350618
# Germany               81.3  357050     Berlin  227.699202       0.833502
# Netherlands           16.9   41526  Amsterdam  406.973944       1.489744
# United Kingdom        64.9  244820  Cambridge  265.092721       0.970382

# %%
countries.iloc[4,2]='London'
countries
# Out:
#                 population    area    capital     density  density_ratio
# country
# Belgium               11.3   30510   Brussels  370.370370       1.355755
# France                64.3  671308      Paris   95.783158       0.350618
# Germany               81.3  357050     Berlin  227.699202       0.833502
# Netherlands           16.9   41526  Amsterdam  406.973944       1.489744
# United Kingdom        64.9  244820     London  265.092721       0.970382

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인구 밀도가 100 초과, 300 미만인 국가들을 표시해주세요.
# </div>

# %%
countries[(countries['density'] > 100) & (countries['density']<300)]
# Out:
#                 population    area capital     density  density_ratio
# country
# Germany               81.3  357050  Berlin  227.699202       0.833502
# United Kingdom        64.9  244820  London  265.092721       0.970382

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 수도가 7글자 이상인 국가들을 표시해주세요. (힌트: string의 len( )를 사용하세요.)
# </div>

# %%
countries[countries['capital'].str.len() >= 7]
# Out:
#              population   area    capital     density  density_ratio
# country
# Belgium            11.3  30510   Brussels  370.370370       1.355755
# Netherlands        16.9  41526  Amsterdam  406.973944       1.489744

# %%
countries['cap_len']=countries['capital'].apply(len)
countries=countries[countries['cap_len']>=7]
countries
# Out:
#              population   area    capital     density  density_ratio  cap_len
# country
# Belgium            11.3  30510   Brussels  370.370370       1.355755        8
# Netherlands        16.9  41526  Amsterdam  406.973944       1.489744        9

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 수도에 'am' 이 포함되는 국가들을 표시해주세요. (힌트: string의 contains( )를 사용하세요.)
# </div>

# %%
countries[countries['capital'].str.contains("am")]
# Out:
#              population   area    capital     density  density_ratio  cap_len
# country
# Netherlands        16.9  41526  Amsterdam  406.973944       1.489744        9

# %% [markdown]
# # 영화리뷰 데이터에서 자료 찾기

# %% [markdown]
# movie_title_data.tsv 읽어오기

# %% [markdown]
# https://drive.google.com/file/d/1cvBtLVyfhfodJK-BXWqBLcopyus9HOIc/view?usp=sharing

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: titles 데이터프레임에는 몇 개의 영화가 기록되어 있나요?
# </div>

# %%
titles=pd.read_csv("./data/movie_title_data.tsv", delimiter="\t")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 titles=pd.read_csv("./data/movie_title_data.tsv", delimiter="\t")
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/movie_title_data.tsv'

# %%
titles.head()

# %%
titles.info(show_counts=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 titles.info(show_counts=True)
#
# NameError: name 'titles' is not defined

# %%
# 데이터 행의 개수
len(titles)

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: titles에서 가장 빠른 시기에 제작된 영화 두 개를 표시하세요.  힌트: .sort_values()
# </div>

# %%
newline_index=titles[titles['startYear'] =="\\N"].index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 titles['startYear'] =="\\N"
#
# NameError: name 'titles' is not defined

# %%
titles.loc[titles['startYear'] =="\\N", 'startYear']=0

# %%
titles.loc[newline_index]

# %%
titles['startYear']=titles['startYear'].astype(int)

# %%
titles['startYear'].dtype

# %%
titles[titles['startYear'] !=0].sort_values(by='startYear').head(2)

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 제목(originalTitle)이 "Hamlet"인 영화는 몇 개가 있나요?
# </div>

# %%
titles[titles['originalTitle'].isna()==False].str.contains("Hamlet")

# %%
no_na_titles=titles[titles['originalTitle'].isna()==False]
len(no_na_titles[no_na_titles['originalTitle'].str.contains("Hamlet")])

# %%
no_na_titles['originalTitle']="Hamlet"

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 제목(originalTitle)이 "Treasure Island"인 영화를 제작년도(startYear)의 오름차순에 따라 표시하세요
# </div>

# %%
titles[(titles['originalTitle'] == 'Treasure Island')& titles['startYear']!=0)].sort_values(by="startYear")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 titles[titles['originalTitle'] == 'Treasure Island'].sort_values(by="startYear")
#
# NameError: name 'titles' is not defined

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 1950년에서 1959년 사이 몇 개의 영화가 만들어졌나요?(1950 <= 제작년도 <= 1959)
# </div>

# %%
len(titles[(titles['startYear']>=1950) & (titles['startYear']<=1959)])

# %% [markdown]
# # 타이타닉 자료에서 그룹별 연산하기

# %% [markdown]
# 원격 DB에 접속해서 titanic 데이터베이스 안에 있는 p_info, t_info, survived 테이블을 불러와 합치고 아래의 문제를 풀어보세요.<br>
# <id:kict00, pw:kict00, ip:221.155.18.165:3306, db:titanic>

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 데이터의 상위 5개 행을 출력하세요.
# </div>

# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb
engine=create_engine("mysql+pymysql://user:password@localhost:3306/titanic")
conn=engine.connect()
p_info=pd.read_sql("p_info", con=conn)
t_info=pd.read_sql("t_info", con=conn)
survived=pd.read_sql("survived", con=conn)
conn.close()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[34], line 5
#       3 pymysql.install_as_MySQLdb
#       4 engine=create_engine("mysql+pymysql://user:password@localhost:3306/titanic")
# ----> 5 conn=engine.connect()
#       6 p_info=pd.read_sql("p_info", con=conn)
#       7 t_info=pd.read_sql("t_info", con=conn)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:3274, in Engine.connect(self)
#    3251 def connect(self) -> Connection:
#    3252     """Return a new :class:`_engine.Connection` object.
#    3253
#    3254     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3271
#    3272     """
# -> 3274     return self._connection_cls(self)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:3298, in Engine.raw_connection(self)
#    3276 def raw_connection(self) -> PoolProxiedConnection:
#    3277     """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279     The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297     """
# -> 3298     return self.pool.connect()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)
#    1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     711     rec = cast(_ConnectionRecord, pool._do_get())
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#     716     dbapi_connection = rec.get_connection()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\impl.py:180, in QueuePool._do_get(self)
#     178     except:
#     179         with util.safe_reraise():
# --> 180             self._dec_overflow()
#     181         raise
#     182 else:
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     673 self.__pool = pool
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\base.py:902, in _ConnectionRecord.__connect(self)
#     900 except BaseException as e:
#     901     with util.safe_reraise():
# --> 902         pool.logger.debug("Error on connect(): %s", e)
#     903 else:
#     904     # in SQLAlchemy 1.4 the first_connect event is not used by
#     905     # the engine, so this will usually not be set
#     906     if pool.dispatch.first_connect:
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\base.py:897, in _ConnectionRecord.__connect(self)
#     895 try:
#     896     self.starttime = time.time()
# --> 897     self.dbapi_connection = connection = pool._invoke_creator(self)
#     898     pool.logger.debug("Created new connection %r", connection)
#     899     self.fresh = True
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\create.py:646, in create_engine.<locals>.connect(connection_record)
#     643         if connection is not None:
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\default.py:625, in DefaultDialect.connect(self, *cargs, **cparams)
#     623 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     624     # inherits the docstring from interfaces.Dialect.connect
# --> 625     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pymysql\connections.py:361, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     359     self._sock = None
#     360 else:
# --> 361     self.connect()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pymysql\connections.py:669, in Connection.connect(self, sock)
#     666 self._next_seq_id = 0
#     668 self._get_server_information()
# --> 669 self._request_authentication()
#     671 # Send "SET NAMES" query on init for:
#     672 # - Ensure charaset (and collation) is set to the server.
#     673 #   - collation_id in handshake packet may be ignored.
#    (...)
#     682 # - https://github.com/wagtail/wagtail/issues/9477
#     683 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#     684 self.set_character_set(self.charset, self.collation)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pymysql\connections.py:979, in Connection._request_authentication(self)
#     977 # https://dev.mysql.com/doc/internals/en/successful-authentication.html
#     978 if self._auth_plugin_name == "caching_sha2_password":
# --> 979     auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     980 elif self._auth_plugin_name == "sha256_password":
#     981     auth_packet = _auth.sha256_password_auth(self, auth_packet)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pymysql\_auth.py:267, in caching_sha2_password_auth(conn, pkt)
#     264     if DEBUG:
#     265         print(conn.server_public_key.decode("ascii"))
# --> 267 data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
#     268 pkt = _roundtrip(conn, data)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pymysql\_auth.py:144, in sha2_rsa_encrypt(password, salt, public_key)
#     139 """Encrypt password with salt and public_key.
#     140
#     141 Used for sha256_password and caching_sha2_password.
#     142 """
#     143 if not _have_cryptography:
# --> 144     raise RuntimeError(
#     145         "'cryptography' package is required for sha256_password or"
#     146         + " caching_sha2_password auth methods"
#     147     )
#     148 message = _xor_password(password + b"\0", salt)
#     149 rsa_key = serialization.load_pem_public_key(public_key, default_backend())
#
# RuntimeError: 'cryptography' package is required for sha256_password or caching_sha2_password auth methods

# %%
data=pd.merge(p_info, t_info, how='inner', on="PassengerId")
data=pd.merge9data, survived, how='inner', on='PassengerId'

# %%
data.head()

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 데이터의 정보(info)를 출력하세요.
# </div>

# %%
data.info()

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 데이터의 기술통계(describe)를 확인하세요.
# </div>

# %%
data.describe(include=all)

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 처음 100명의 데이터를 출력하세요.
# </div>

# %%
data.loc[:99,:]

# %%
data.iloc[:100, :]

# %%
pd.set_option('display.max_rows', 100)
data.head(100)

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인덱스가 10~20인 데이터를 출력하세요.
# </div>

# %%
data.loc[10:20, : ]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 컬럼 이름을 모두 출력하세요.
# </div>

# %%
data.columns

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 데이터의 shape를 확인하세요.
# </div>

# %%
data.shape

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Age' 컬럼의 평균을 구하세요.
# </div>

# %%
data['Age'].mean()

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Survived' 컬럼의 고유값을 확인하세요.
# </div>

# %%
data['Survived'].unique

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 나이가 30 이상인 승객만 출력하세요.
# </div>

# %%
data['Age']>=30

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 성별이 'female'이고 생존한 승객만 출력하세요.
# </div>

# %%
data[(data['Sex']=='female')&(data['Survived']==1)]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 나이가 10살 이하이고 요금이 20 이상인 승객을 출력하세요.
# </div>

# %%
data[(data['Age']<=10) & (data['Fare']>=20)]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 나이가 결측치인 데이터를 출력하세요.
# </div>

# %%
data[data['Age'].isna()==True]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 나이를 기준으로 오름차순 정렬하세요.
# </div>

# %%
data[data['Age'].isna() == False].sort_values(by='Age')

# %%
data.sort_values(by="Age")

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 요금을 기준으로 내림차순 정렬하고 상위 5명만 출력하세요.
# </div>

# %%
data['Fare'].sort_values(by='Fare', ascending=False)[:5]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 성별로 그룹화하여 생존률 평균을 구하세요.
# </div>

# %%
data[['Sex','Survived']].groupby('Sex').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 data[['Sex','Survived']].groupby('Sex').mean()
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: Pclass별 평균 나이를 구하세요.
# </div>

# %%
data[['Pclass','Age']].groupby('Pclass').mean()

# %%
data.groupby('Pclass')[[Age']].mean()

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Age'에 10을 더한 값을 새로운 컬럼 'Age_plus_10'으로 추가하세요.
# </div>

# %%
data['Age_plus_10']=data['Age']+10
data

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Age'가 18 이상이면 '성인', 아니면 '미성년'으로 분류하는 컬럼을 추가하세요.
# </div>

# %%
data['isAdult']=data['Age'].apply(lambda x:"성인" if x > =18 else "미성년")

# %%
data['Age'].apply(lambda x:np.where(x>=18,"성인","미성년"))

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Age'의 결측치를 평균으로 채우세요.
# </div>

# %%
age_na_index=data[data['Age'].isna()].index

# %%
data['Age'].mean()

# %%
data['Age']=data['Age'].fillna(data['Age'].mean())

# %%
data.loc[]

# %%
data['Age'].isna().sum()

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Cabin' 컬럼의 결측치를 'Unknown'으로 채우세요.
# </div>

# %%
cabin_na_idx=data[data['Cabin'].isna()].index

# %%
data['Cabin']=data['Cabin'].fillna('Unknown')

# %%
data.loc[cabin_]

# %%
data['Cabin'].isna().sum()

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 중복된 'Ticket' 값을 제거하고 몇 개가 남는지 출력하세요.
# </div>

# %%
data['Ticket'].duplicated()

# %%
daata=data.drop_duplicates(subset='Ticket')
data['Ticket'].duplicated().sum()

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Embarked' 컬럼의 고유값과 각각의 개수를 출력하세요.
# </div>

# %%
data['Embarked'].value_counts()

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인덱스를 'PassengerId'로 설정하세요.
# </div>

# %%
data=data.set_index('PassengerId')
data

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인덱스를 초기화하세요.
# </div>

# %%
data=data.reset_index()
data

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 성별과 Pclass의 생존률을 피벗 테이블로 만드세요.
# </div>

# %%
data.pivot_table(values='Survived', index='Pclass', columns='Sex')

# %%
data.pivot_table(values='Survived', index='Sex', columns='Pclass')

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: groupby()를 사용하여 각 성별(sex)의 평균 나이(age)를 구하세요.
# </div>

# %%
data[['Sex','Age']].groupby('Sex').mean()

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 전체 승객(passenger)의 평균 생존율을 구하세요.
# </div>

# %%
data['Survived'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 data['Survived'].mean()
#
# KeyError: 'Survived'

# %%
data['Survived'].sum()/len(data['Survived'])

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 25세 이하 승객의 생존율을 구하세요. (힌트: 불리언 인덱싱)
# </div>

# %%
data.loc[data['Age']<=25, 'Survived'].mean()

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 남성의 생존율을 구하세요. 여성의 생존율을 구하세요. (힌트: 불리언 인덱싱)
# </div>

# %%
print("남성의 생존율:", data.loc[data['Sex']=='male', 'Survived'].mean())
print("여성의 생존율:", data.loc[data['Sex']=='female', 'Survived'].mean())

# %%
data['Sex','Survived'].grouby('Sex').mean()

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 생존율을 구하는 함수가 작성되어 있습니다. 성별 생존율을 groupby를 활용해 구하기 위해 ?부분을 알맞게 채워주세요.
# </div>

# %%
def survival_ratio(survived):
    return survived.sum() / len(survived)

# %%
data[['Sex','Survived']].groupby('Sex').agg(['survival_ratio'])

# %%
for i in sy_unique:
    print(i, type(i))

# %%
countries['density']=countries['population']*1000000/countries['area']

# %%
countries.loc[countries['density']>300]

# %%
countries['density'].mean()

# %%
countries.loc['United Kingdom', 'capital']='Cambridge'
countries

# %%
countries.iloc[4,2]='London'

# %%
countries[(countries['density']>100)& (coountries)]

# %%
countries[countries['capital'].str.len()>=7]

# %%
countries[countries['captial'].apply(len)>=7]

# %%
countries['cap_len']=countries['captial'].apply(len)

# %%
countries[countries['captial'].str.contains("am")]

# %%
titles=pd.read_csv("./data/movie_title_data.tsv", delimiter="\t")

# %%
# 숫자 + 문자이면 다 문자로 바꿔버림. unique 했는데 앞쪽에 공백이 있으면 공백 다 제거할 것
titles['startYear'].unique

# %%
titles['startYear']=titles['startYear'].str.strip()

# %%
len(titles)

# %%
newline_index=titles[titles['startYear']=="\\N"].index

# %%
titles['startYear']=titles['startYear'].astype(int)

# %%
titles[titles['startYear']!=0].sort_values(by='startYear').head(2)

# %%
#isna()->  결측값 찾는 함수
no_na_titles=titles[titles['or']]

# %%
import pandas as pd
from sqlalchemy import create_engine
p_info=pd.read_sql
conn.close()

# %%
data=pd.merge(p_info, t_info, how='inner', on="PassengerId")

# %%
data.head()

# %%
data.info()

# %%
data.describe()

# %%
pd.set_option('display.max_rows',100)

# %%
data.loc[10:20, :]

# %%
data['Age'].mean()

# %%
data[data['Age'].isna()]

# %%
data.sort_values(by='Age')

# %%
data.sort_values(by='Fare', ascending=False).head()

# %%
data[['Sex','Survived']].groupby('Sex')

# %%
data['Pclass','Age'].groupby('Pclass').mean()

# %%
data['Age_plus_10']=data['Age']+10

# %%
data['isAdult']=data['Age'].apply(lambda x)

# %%
data['Age'].apply(lambda x:np.where(x>18))

# %%
data['Age'].mean()

# %%
data.loc[age_na_index]

# %%
cabin_na_idx=data[data['Cabin'].isna()].index

# %%
data[data['Ticket']].duplicated()

# %%
data=data.drop_duplicates(subset='Ticket')
data['Ticket'].duplicated().sum()

# %%
data['Embarked'].value

# %%
data=data.set_index

# %%
data.loc[data['Age']<=25, "Survived"].mean()

# %%
data.loc[data['Sex']=='male','Survived'].mean()

# %%
data['Sex','Survived']
