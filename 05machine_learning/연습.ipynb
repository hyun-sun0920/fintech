# %%
fig=plt.figure()
plt.show()

# %%
fig, ax=plt.subplots()
plt.show()

# %%
fig, ax=plt.subplots(2,2)

# %%
fig, ax=plt.subplots(3,2)
print(ax.shape)

# %%
fig, axes = plt.subplot_mosaic([['letf','right_top'],['left','right_bottom']])
plt.show()

# %%
fig, axes= plt.subplot_mosaic([['left','right'],['left','right']])
plt.show()

# %%
fig, axes=plt.subplot_mosaic(['top','top'],['left','right'])

# %%
x=np.linspace(0,2,100)

# %%
fig, ax=plt.subplots(figsize=(5, 2.7))
ax.plot(x,x, label='linear')
ax.plot(x,x**2, label='quadratic')
ax.plot(x,x**3, label='cubic')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title('간단 그래프')
ax.legend()
plt.show()

# %%
fig, axs=plt.subplots(2,2, figsize=(10,6))
axs[0,0].plot(x, y, label='Plot1')
axs[0,0].set_title()

# %%
plt.figure(figsize=(5,2.7))

# %%
fig, ax = plt.subplots(figsize=(5,2.7))
x=np.arange(len(data1))
ax.plot(x, np.cumsum(data1), color='blue',linewidth=3, linestyle="--")

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.scatter(data1, data2, s=100, facecolor=(0.1,0.6,0.8), edgecolor='k')
plt.show()

# %%
ax.scatter(data1, data2, s=100, facecolor='C0', edgecolor='k')

# %%
x=mu+sigma*np.random.randn(100000)
fig, ax=plt.subplots
n, bins, patches=ax.hist(x, 50, density=True, facecolor='C0', alpha=0.75)
ax.text
ax.axis([55, 175, 0, 0.03])
ax.axis('off')
plt.show()

# %%
xdata=np.arange(len(data1))
fig, ax=plt.su
ax[0].plot(xdata, )

# %%
fig, ax=plt.subplots(figsize=(5, 2.7))
ax.bar(categories, np.random.rand(len(categories)))

# %%
import pandas as pd
import numpy as np

# %%
data.isna().sum()/len(data) * 100

# %%
age_na_index2=data2[data2['Age'].isna()].index
