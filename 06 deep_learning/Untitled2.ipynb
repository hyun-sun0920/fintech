# %%
for col in missing_cols:
    if data[col].dtype=='object':
        data[col]=data[col].fillna(data[col].mode()[0])
    else:
        data[col]=data[col].fillna(data[col].median()[0])

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/fintech/miniforge3/envs/face/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/fintech/miniforge3/envs/face/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/fintech/miniforge3/envs/face/lib/python3.10/site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fintech/miniforge3/envs/face/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/fintech/miniforge3/envs/face/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fintech/miniforge3/envs/face/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fintech/miniforge3/envs/face/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/fintech/miniforge3/envs/face/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/fintech/miniforge3/envs/face/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/fintech/miniforge3/envs/face/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fintech/miniforge3/envs/face/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/fintech/miniforge3/envs/face/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/fintech/miniforge3/envs/face/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/fintech/miniforge3/envs/face/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data2=data.copy()
data3=data.copy()

# %%
X=data.drop(['SalePrice', 'Id'], axis=1)
y=data['SalePrice']

# %%
X=pd.get_dummies(X)
X.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 X
#
# NameError: name 'X' is not defined

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler

# %%
X_train, X_valid, y_train, y_valid=train_test_split(X, y, test_size=0.3, random_state=42)

# %%
rs=RobustScaler()
rs_X_train=rs.fit_transform(X_train)
rs_X_test=rs.transform(X_valid)

# %%
import joblib
joblib.dump(rs, "./model/iowa_rs.joblib")

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.metrics import RootMeanSquaredError

# %%
inputs=input(shape=(rs_X_train.shape[1], ))
x=Dense(32, activation='relu')(inputs)
x=Dense(16, activation='relu')(x)
x=Dropout(0.3)(x)
x=Dense(1)(x)
base_model=Model(inputs=inputs, outputs=outputs)
base_model.summary()

# %%
base_model.compile(loss='mean_squared_error', optimizer='adam', metrics=[RootMeanSquared])
early_stop=EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_path="./model/iowa_base_model_best.keras"
check_point=ModelCheckpoint(filepath=model_path, moniot='val_loss', save_best_only=True, verbose=1)
base_model_history=base_model.fit(rs_X_train, y_train, epochs=1000, batch_size=32, validation_data=(rs_X_valid, y_valid), callbacks=[early_stop, check_point], verbp)

# %%
pred=base_model.predict(rs_X_valid)
pred=pd.DataFrame(pred, columns=['pred'])

# %%
y_valid=pd.DataFrame(y_valid)
y_valid_df=y_valid.reset_index(drop=True)
final_result=y_valid_df.join(pred)
final_result

# %%
plt.figure(figsize=(10,5))
plt.plot(final_result['SalePrice'],label='SalePrice')
plt.plot(final_result['pred'], label='pred')
plt.legend()
plt.show()
print(base_model.evaluate(rs_X_valid, y_valid))

# %% [markdown]
# # 많은 컬럼 중에 어떤 컬럼을 선택? 266개
# * 컬럼의 상관분석을 통해 타겟 변수(종속변수)와 상관도가 높은 컬럼만 선택
# * 트리계열 알고리즘을 사용해 분석 후 중요한 변수만 추출해서 재분석

# %%
data2.drop("Id", axis=1, inplace=True)
data2=pd.get_dummies(data2)

# %%
data2.head(2)

# %% [markdown]
# 상관분석

# %%
data2['SalePrice']

# %%
corr_rate=data2.corr(method='spearman')['SalePrice'].sort_values(ascending=False)

# %%
new_cols1=corr_rate.head(15).index
new_cols1

# %%
final_cols=list(new_cols)

# %%
final_cols

# %%
plt, figure(figsize=(20, 20))
sns.heatmap(final_df.corr(method='spearman'), annot=True, linewidth)

# %%
ExterQual_TA-e
